# %% [markdown]
# # Notebook 5: Composing Examples
#
# In this notebook we will examine how we can use the elements we have encountered so far, in order to construct a examples which will allow us to train machine learning models with data generated in real time. This is a core functionality of GravyFlow.
#
# As usual, we begin by performing the relevent imports:

# %%
# Built-in imports
from typing import List, Dict, Iterator
from pathlib import Path

# Dependency imports: 
import numpy as np
import tensorflow as tf
from bokeh.io import show, output_notebook
from bokeh.layouts import gridplot

# Import the GravyFlow module.
import gravyflow as gf
# Out:
# 2024-08-20 10:04:42.448662: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# And creating a TensorFlow GPU stratergy:

# %%
# Set up the environment using gf.env() and return a tf.distribute.Strategy object.
env : tf.distribute.Strategy = gf.env()
# Out:
# INFO:root:TensorFlow version: 2.12.1, CUDA version: 11.8
# 2024-08-20 10:05:03.301082: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-08-20 10:05:03.301159: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3000 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:0b:00.0, compute capability: 7.0
# INFO:root:[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Creating an example generator through composition
#
# We can combine all the elements we have seen so, noise generation, waveform generation, and waveform projection, and use MLy to create a custom Python generator.
#
# In order to scale the injection with respect to the noise we can use a `gf.ScalingMethod` object. GravyFlow supports scaling with SNR (`gf.ScalingTypes.SNR`), HRSS (`gf.ScalingTypes.HRSS`), and HPEAK (`gf.ScalingTypes.HPEAK`).
#
# - `value` : `Union[gf.Distribution, np.ndarray]`, Required
#   > The value or distribution to use to scale the injections, units vary depending on type parameter.
#
# - `type_` : `gf.ScalingTypes`, Required
#   > Type of scaling, one of either `gf.ScalingTypes.SNR`, `gf.ScalingTypes.HRSS`, or `gf.ScalingTypes.HPEAK`.
#
# Let us create a `gf.ScalingMethod` object:

# %%
# Create a scaling method object in order to scale the injection to the noise:
scaling_method : gf.ScalingMethod = gf.ScalingMethod(
    value=gf.Distribution(
        value=20,
        type_=gf.DistributionType.CONSTANT
    ),
    type_=gf.ScalingTypes.SNR
)

# %% [markdown]
# Next, we can set up all the other elements that we can use to compose or example generator:

# %%
with env:
    # This object will be used to obtain real interferometer data based on specified parameters.
    ifo_data_obtainer : gf.IFODataObtainer = gf.IFODataObtainer(
        observing_runs=gf.ObservingRun.O3, # Specify the observing run (e.g., O3).
        data_quality=gf.DataQuality.BEST,  # Choose the quality of the data (e.g., BEST).
        data_labels=[                      # Define the types of data to include.
            gf.DataLabel.NOISE, 
            gf.DataLabel.GLITCHES
        ],
        segment_order=gf.SegmentOrder.RANDOM, # Order of segment retrieval (e.g., RANDOM).
        force_acquisition=True,               # Force the acquisition of new data.
        cache_segments=False                  # Choose not to cache the segments.
    )

    # Initialize the noise generator wrapper:
    # This wrapper will use the ifo_data_obtainer to generate real noise based on the specified parameters.
    noise: gf.NoiseObtainer = gf.NoiseObtainer(
        ifo_data_obtainer=ifo_data_obtainer, # Use the previously set up IFODataObtainer object.
        noise_type=gf.NoiseType.REAL,        # Specify the type of noise as REAL.
        ifos=gf.IFO.L1 # Specify the interferometer (e.g., LIGO Livingston L1).
    )

    # Define a uniform distribution for the mass of the first object in solar masses.
    mass_1_distribution_msun : gf.Distribution = gf.Distribution(
        min_=10.0, 
        max_=60.0, 
        type_=gf.DistributionType.UNIFORM
    )

    # Define a uniform distribution for the mass of the second object in solar masses.
    mass_2_distribution_msun : gf.Distribution = gf.Distribution(
        min_=10.0, 
        max_=60.0, 
        type_=gf.DistributionType.UNIFORM
    )

    # Define a uniform distribution for the inclination of the binary system in radians.
    inclination_distribution_radians : gf.Distribution = gf.Distribution(
        min_=0.0, 
        max_=np.pi, 
        type_=gf.DistributionType.UNIFORM
    )

    # Initialize a PhenomD waveform generator with the defined distributions.
    # This generator will produce waveforms with randomly varied masses and inclination angles.
    phenom_d_generator : gf.WaveformGenerator = gf.RippleGenerator(
        mass_1_msun=mass_1_distribution_msun,
        mass_2_msun=mass_2_distribution_msun,
        inclination_radians=inclination_distribution_radians,
        scaling_method=scaling_method,
        injection_chance=1.0 # Set so half produced examples will not contain this signal
    )
    
    generator : Iterator = gf.data(       
        noise_obtainer=noise,
        waveform_generators=phenom_d_generator,
        num_examples_per_batch=8,
        input_variables=[
            gf.ReturnVariables.WHITENED_ONSOURCE, 
        ],
        output_variables=[
            gf.ReturnVariables.INJECTIONS, 
            gf.ReturnVariables.WHITENED_INJECTIONS,
            gf.ReturnVariables.INJECTION_MASKS
        ]
    )
# Out:
# 2024-08-20 10:05:03.485856: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x56088f220350 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-08-20 10:05:03.485897: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2024-08-20 10:05:03.491292: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-20 10:05:03.529079: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2024-08-20 10:05:03.695335: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# INFO:root:Loading event times from cache.

# %% [markdown]
# Similiarly to the individual elements, we can use this example generator as an iterator, and produce N examples for use to examine:

# %%
# Use the TensorFlow environment 'env' created earlier with gf.env()
with env:
    # Generate a batch of examples using the composed generator.
    input_data, output_data = next(generator)
# Out:
# 2024-08-20 10:05:17.688792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{node PartitionedCall_1}}]]
# 2024-08-20 10:05:17.689392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{node PartitionedCall_2}}]]
# 2024-08-20 10:05:17.694703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{node PartitionedCall_1}}]]
# 2024-08-20 10:05:17.694985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{node PartitionedCall_2}}]]
# 2024-08-20 10:05:17.717592: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{node PartitionedCall_1}}]]
# 2024-08-20 10:05:17.717848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{node PartitionedCall_2}}]]
# 2024-08-20 10:05:17.718307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{node PartitionedCall_1}}]]
# 2024-08-20 10:05:17.718572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{node PartitionedCall_2}}]]
# 2024-08-20 10:05:17.730957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{function_node __inference_snr_1525}}{{node PartitionedCall_2}}]]
# 2024-08-20 10:05:17.735247: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{function_node __inference_psd_1399}}{{node PartitionedCall}}]]
# 2024-08-20 10:05:19.616721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{function_node __inference_psd_1705}}{{node PartitionedCall}}]]
# 2024-08-20 10:05:19.624242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{function_node __inference_truncate_transfer_1842}}{{node PartitionedCall}}]]
# 2024-08-20 10:05:20.155324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{function_node __inference_psd_1705}}{{node PartitionedCall}}]]
# 2024-08-20 10:05:20.162884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INTERNAL: No function library is provided.
# 	 [[{{function_node __inference_truncate_transfer_2267}}{{node PartitionedCall}}]]

# %%
import cProfile
import pstats
from pstats import SortKey

def function_to_profile():
    # Your code here
    with env:
    	# Generate a batch of examples using the composed generator.
    	input_data, output_data = next(generator)

# Run the profiler
cProfile.run('function_to_profile()', 'profile_output')

# Analyze the results
p = pstats.Stats('profile_output')
p.strip_dirs().sort_stats(SortKey.TIME).print_stats(344)
# Out:
# Tue Aug 20 10:05:22 2024    profile_output
#
#          14544 function calls (14004 primitive calls) in 0.021 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        13    0.004    0.000    0.004    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_Execute}
#        15    0.002    0.000    0.002    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_FastPathExecute}
#        10    0.001    0.000    0.002    0.000 constant_op.py:75(convert_to_eager_tensor)
#         3    0.001    0.000    0.002    0.001 math_ops.py:938(cast)
#        77    0.001    0.000    0.001    0.000 typing.py:1408(_get_protocol_attrs)
#        39    0.001    0.000    0.001    0.000 inspect.py:3050(_bind)
#        13    0.000    0.000    0.004    0.000 function_type.py:368(canonicalize_to_monomorphic)
#      1143    0.000    0.000    0.002    0.000 {built-in method builtins.isinstance}
#        91    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.Flatten}
#        13    0.000    0.000    0.004    0.000 monomorphic_function.py:344(call)
#        13    0.000    0.000    0.015    0.001 polymorphic_function.py:866(__call__)
#     49/47    0.000    0.000    0.002    0.000 trace_type_builder.py:159(from_value)
#        94    0.000    0.000    0.001    0.000 function_type.py:135(__eq__)
#       158    0.000    0.000    0.000    0.000 dtypes.py:234(__eq__)
#       255    0.000    0.000    0.000    0.000 function_type.py:166(parameters)
#       363    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        13    0.000    0.000    0.005    0.000 monomorphic_function.py:1679(_call_flat)
#       322    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        82    0.000    0.000    0.000    0.000 context.py:976(executing_eagerly)
#      1001    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#     22/14    0.000    0.000    0.005    0.000 dispatch.py:1162(op_dispatch_handler)
#    283/97    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 {method '_numpy_internal' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        13    0.000    0.000    0.014    0.001 polymorphic_function.py:913(_call)
#       329    0.000    0.000    0.000    0.000 function_type.py:97(type_constraint)
#        49    0.000    0.000    0.001    0.000 typing.py:1490(__instancecheck__)
#        26    0.000    0.000    0.000    0.000 inspect.py:2787(args)
#         1    0.000    0.000    0.009    0.009 injection.py:1074(add_injections_to_onsource)
#      1105    0.000    0.000    0.000    0.000 inspect.py:2699(kind)
#        13    0.000    0.000    0.000    0.000 weakref.py:455(__contains__)
#        13    0.000    0.000    0.001    0.000 function_spec.py:413(bind_function_inputs)
#        26    0.000    0.000    0.001    0.000 function_spec.py:488(cast_numpy_inputs)
#        47    0.000    0.000    0.000    0.000 inspect.py:2637(__init__)
#        94    0.000    0.000    0.000    0.000 function_type.py:143(__hash__)
#        47    0.000    0.000    0.000    0.000 function_type.py:51(__init__)
#        26    0.000    0.000    0.000    0.000 inspect.py:2840(apply_defaults)
#       363    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#        13    0.000    0.000    0.014    0.001 tracing_compiler.py:138(__call__)
#        21    0.000    0.000    0.001    0.000 ops.py:1037(__tf_tracing_type__)
#        26    0.000    0.000    0.001    0.000 function_type.py:306(__eq__)
#        13    0.000    0.000    0.000    0.000 inspect.py:2920(__init__)
#        13    0.000    0.000    0.000    0.000 function_context.py:39(make_function_context)
#       145    0.000    0.000    0.000    0.000 ops.py:1130(dtype)
#        41    0.000    0.000    0.000    0.000 tensor_shape.py:815(__init__)
#         1    0.000    0.000    0.000    0.000 {numpy.random._generator.default_rng}
#        13    0.000    0.000    0.001    0.000 function_type.py:221(bind_with_defaults)
#     334/1    0.000    0.000    0.021    0.021 {built-in method builtins.next}
#        47    0.000    0.000    0.003    0.000 function_type.py:357(_make_validated_mono_param)
#        52    0.000    0.000    0.000    0.000 composite_tensor_utils.py:24(flatten_with_variables)
#        26    0.000    0.000    0.000    0.000 dtypes.py:773(as_dtype)
#        13    0.000    0.000    0.000    0.000 monomorphic_function.py:2102(_build_call_outputs)
#       282    0.000    0.000    0.000    0.000 function_type.py:92(optional)
#       599    0.000    0.000    0.000    0.000 inspect.py:2687(name)
#     36/27    0.000    0.000    0.019    0.001 traceback_utils.py:138(error_handler)
#        18    0.000    0.000    0.002    0.000 ops.py:1574(convert_to_tensor)
#         2    0.000    0.000    0.000    0.000 {method 'integers' of 'numpy.random._generator.Generator' objects}
#       611    0.000    0.000    0.000    0.000 inspect.py:2695(annotation)
#        13    0.000    0.000    0.008    0.001 tracing_compiler.py:321(_maybe_define_function)
#         1    0.000    0.000    0.000    0.000 {function SeedSequence.generate_state at 0x7fc7f86dbeb0}
#        42    0.000    0.000    0.000    0.000 tensor_spec.py:118(__eq__)
#        49    0.000    0.000    0.001    0.000 typing.py:1425(_is_callable_members_only)
#        68    0.000    0.000    0.000    0.000 ops.py:6362(get_default_graph)
#        30    0.000    0.000    0.000    0.000 handle_data_util.py:26(copy_handle_data)
#        26    0.000    0.000    0.000    0.000 inspect.py:2810(kwargs)
#         1    0.000    0.000    0.021    0.021 dataset.py:224(__next__)
#        91    0.000    0.000    0.000    0.000 nest.py:356(flatten)
#         1    0.000    0.000    0.005    0.005 acquisition.py:1449(get_onsource_offsource_chunks)
#        26    0.000    0.000    0.001    0.000 function_type.py:313(__hash__)
#        13    0.000    0.000    0.002    0.000 function_cache.py:46(lookup)
#        47    0.000    0.000    0.000    0.000 enum.py:359(__call__)
#        52    0.000    0.000    0.000    0.000 default_types.py:97(__eq__)
#        25    0.000    0.000    0.000    0.000 context.py:2166(executing_eagerly)
#        98    0.000    0.000    0.000    0.000 typing.py:1427(<genexpr>)
#        13    0.000    0.000    0.002    0.000 function_spec.py:373(canonicalize_function_inputs)
#        10    0.000    0.000    0.000    0.000 control_flow_ops.py:598(__init__)
#        26    0.000    0.000    0.000    0.000 polymorphic_function.py:829(experimental_get_tracing_count)
#       140    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        13    0.000    0.000    0.000    0.000 monomorphic_function.py:1955(captured_inputs)
#        25    0.000    0.000    0.000    0.000 ops.py:1257(shape)
#       408    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.001    0.001 array_ops.py:931(_slice_helper)
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        13    0.000    0.000    0.004    0.000 function_spec.py:328(make_canonicalized_monomorphic_type)
#        92    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       255    0.000    0.000    0.000    0.000 inspect.py:3006(parameters)
#        71    0.000    0.000    0.000    0.000 tensor_shape.py:825(<genexpr>)
#        68    0.000    0.000    0.000    0.000 ops.py:5896(get_default)
#        22    0.000    0.000    0.000    0.000 {method '_shape_tuple' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        21    0.000    0.000    0.000    0.000 tensor_spec.py:75(__init__)
#         1    0.000    0.000    0.002    0.002 injection.py:986(generate_scaling_parameters_)
#        13    0.000    0.000    0.000    0.000 function_spec.py:574(filter_function_inputs)
#        57    0.000    0.000    0.000    0.000 tensor_shape.py:723(as_dimension)
#        15    0.000    0.000    0.000    0.000 nest.py:652(_pack_sequence_as)
#        13    0.000    0.000    0.000    0.000 polymorphic_function.py:509(__init__)
#        13    0.000    0.000    0.004    0.000 execute.py:27(quick_execute)
#         5    0.000    0.000    0.000    0.000 nest.py:185(_sequence_like)
#        13    0.000    0.000    0.000    0.000 polymorphic_function.py:193(called_without_tracing)
#       354    0.000    0.000    0.000    0.000 inspect.py:2691(default)
#        45    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsNestedOrComposite}
#       145    0.000    0.000    0.000    0.000 {method '_datatype_enum' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        13    0.000    0.000    0.000    0.000 polymorphic_function.py:170(called_without_tracing)
#        42    0.000    0.000    0.000    0.000 tensor_spec.py:115(__hash__)
#         8    0.000    0.000    0.000    0.000 function_type.py:343(<listcomp>)
#         1    0.000    0.000    0.000    0.000 contextlib.py:76(inner)
#        39    0.000    0.000    0.001    0.000 inspect.py:3181(bind)
#        43    0.000    0.000    0.000    0.000 tensor_shape.py:1428(__eq__)
#        13    0.000    0.000    0.001    0.000 type_dispatch.py:75(dispatch)
#         1    0.000    0.000    0.003    0.003 dataset.py:310(_process_onsource)
#        13    0.000    0.000    0.000    0.000 polymorphic_function.py:188(_get_detector)
#        49    0.000    0.000    0.000    0.000 trace_type_builder.py:91(is_legacy_signature)
#        10    0.000    0.000    0.000    0.000 control_flow_util.py:64(InXlaContext)
#        61    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        13    0.000    0.000    0.000    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetIsEmpty}
#        13    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#        52    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        60    0.000    0.000    0.000    0.000 function_type.py:388(<genexpr>)
#        10    0.000    0.000    0.002    0.000 constant_op.py:272(_constant_impl)
#        13    0.000    0.000    0.000    0.000 function_type.py:159(__init__)
#        11    0.000    0.000    0.000    0.000 array_ops.py:1584(_should_not_autopack)
#        18    0.000    0.000    0.002    0.000 trace.py:178(wrapped)
#        10    0.000    0.000    0.000    0.000 control_flow_util.py:69(GraphOrParentsInXlaContext)
#        10    0.000    0.000    0.000    0.000 control_flow_ops.py:694(Exit)
#        56    0.000    0.000    0.000    0.000 typing.py:1506(<genexpr>)
#       104    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#        57    0.000    0.000    0.000    0.000 tensor_shape.py:199(__init__)
#         2    0.000    0.000    0.000    0.000 injection.py:767(__call__)
#         1    0.000    0.000    0.021    0.021 {built-in method builtins.exec}
#        13    0.000    0.000    0.000    0.000 save_context.py:59(in_save_context)
#       5/3    0.000    0.000    0.000    0.000 nest.py:612(_packed_nest_with_indices)
#        13    0.000    0.000    0.000    0.000 context.py:1270(function_call_options)
#         2    0.000    0.000    0.000    0.000 array_ops.py:1618(unstack)
#         1    0.000    0.000    0.005    0.005 acquisition.py:400(random_subsection)
#        13    0.000    0.000    0.000    0.000 monomorphic_function.py:113(__init__)
#         1    0.000    0.000    0.002    0.002 injection.py:52(scale)
#        78    0.000    0.000    0.000    0.000 function_type.py:170(captures)
#        65    0.000    0.000    0.000    0.000 inspect.py:2779(__init__)
#         6    0.000    0.000    0.000    0.000 ops.py:6767(name_scope)
#        10    0.000    0.000    0.000    0.000 control_flow_ops.py:688(Enter)
#        10    0.000    0.000    0.000    0.000 control_flow_ops.py:3790(__init__)
#        78    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        13    0.000    0.000    0.000    0.000 function_spec.py:584(<listcomp>)
#        45    0.000    0.000    0.000    0.000 enum.py:783(__hash__)
#         1    0.000    0.000    0.001    0.001 tensor_conversion_registry.py:46(_default_conversion_function)
#         1    0.000    0.000    0.000    0.000 distribute_lib.py:389(__enter__)
#        52    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        13    0.000    0.000    0.000    0.000 trace_type_builder.py:61(__init__)
#        36    0.000    0.000    0.000    0.000 traceback_utils.py:32(is_traceback_filtering_enabled)
#        12    0.000    0.000    0.000    0.000 tensor_conversion_registry.py:112(get)
#        73    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        77    0.000    0.000    0.000    0.000 {method 'keys' of 'mappingproxy' objects}
#        26    0.000    0.000    0.000    0.000 default_types.py:32(__init__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#        10    0.000    0.000    0.002    0.000 constant_op.py:303(_constant_eager_impl)
#         4    0.000    0.000    0.000    0.000 array_ops.py:1499(_autopacking_helper)
#         2    0.000    0.000    0.000    0.000 dataset.py:452(create_variable_dictionary)
#        23    0.000    0.000    0.000    0.000 context.py:998(device_name)
#        26    0.000    0.000    0.000    0.000 monomorphic_function.py:274(signature)
#        13    0.000    0.000    0.000    0.000 weakref.py:415(__getitem__)
#        13    0.000    0.000    0.001    0.000 function_spec.py:477(cast_inputs)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:33(seterr)
#        43    0.000    0.000    0.000    0.000 tensor_shape.py:1495(as_shape)
#        15    0.000    0.000    0.000    0.000 ops.py:5463(_distribution_strategy_stack)
#        10    0.000    0.000    0.001    0.000 array_ops.py:1434(stack)
#        52    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#         3    0.000    0.000    0.001    0.000 gen_math_ops.py:1980(cast)
#        13    0.000    0.000    0.000    0.000 capture_container.py:89(get_by_ref_snapshot)
#         4    0.000    0.000    0.000    0.000 gen_array_ops.py:6535(pack)
#         1    0.000    0.000    0.000    0.000 tensor.py:53(sample)
#        42    0.000    0.000    0.000    0.000 tensor_shape.py:1483(__hash__)
#        11    0.000    0.000    0.001    0.000 array_ops.py:1594(_autopacking_conversion_function)
#        13    0.000    0.000    0.000    0.000 polymorphic_function.py:519(__exit__)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        29    0.000    0.000    0.000    0.000 array_ops.py:1590(<genexpr>)
#         1    0.000    0.000    0.000    0.000 math_ops.py:1451(binary_op_wrapper)
#         8    0.000    0.000    0.000    0.000 function_type.py:327(sanitize_arg_name)
#        47    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        13    0.000    0.000    0.000    0.000 tape.py:220(could_possibly_record)
#       178    0.000    0.000    0.000    0.000 {method 'isalnum' of 'str' objects}
#        69    0.000    0.000    0.000    0.000 context.py:2136(context_safe)
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsNamedtuple}
#         1    0.000    0.000    0.003    0.003 dataset.py:294(_process_whitened_injections)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:430(__enter__)
#        84    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        47    0.000    0.000    0.000    0.000 enum.py:678(__new__)
#        15    0.000    0.000    0.000    0.000 nest.py:692(pack_sequence_as)
#        13    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#        13    0.000    0.000    0.000    0.000 {built-in method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetPossibleGradientTypes}
#        20    0.000    0.000    0.000    0.000 nest.py:256(_yield_value)
#        20    0.000    0.000    0.000    0.000 nest.py:261(_yield_sorted_items)
#         1    0.000    0.000    0.003    0.003 injection.py:1048(generate_scaling_parameters)
#        26    0.000    0.000    0.000    0.000 util.py:25(is_attrs)
#        77    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 injection.py:843(generate_one)
#         8    0.000    0.000    0.000    0.000 dtypes.py:69(_is_ref_dtype)
#         4    0.000    0.000    0.001    0.000 ops.py:7371(__next__)
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:11383(_sum)
#        13    0.000    0.000    0.000    0.000 gradients_util.py:1046(PossibleTapeGradientTypes)
#         1    0.000    0.000    0.021    0.021 2029455450.py:5(function_to_profile)
#        13    0.000    0.000    0.000    0.000 trace_type_builder.py:38(__init__)
#        23    0.000    0.000    0.000    0.000 context.py:558(ensure_initialized)
#        13    0.000    0.000    0.000    0.000 function_spec.py:415(<dictcomp>)
#        26    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x56088b4a35e0}
#        13    0.000    0.000    0.000    0.000 tracing_compiler.py:155(input_signature)
#        42    0.000    0.000    0.000    0.000 tensor_spec.py:96(dtype)
#         2    0.000    0.000    0.000    0.000 gen_array_ops.py:10553(strided_slice)
#        10    0.000    0.000    0.002    0.000 constant_op.py:171(constant)
#         2    0.000    0.000    0.000    0.000 array_ops.py:1185(strided_slice)
#        13    0.000    0.000    0.000    0.000 trace.py:50(__init__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        20    0.000    0.000    0.000    0.000 ops.py:3476(_set_control_flow_context)
#         2    0.000    0.000    0.000    0.000 gen_array_ops.py:12365(unpack)
#         1    0.000    0.000    0.000    0.000 math_ops.py:1781(_add_dispatch)
#        52    0.000    0.000    0.000    0.000 default_types.py:103(__hash__)
#         2    0.000    0.000    0.000    0.000 ops.py:7020(__enter__)
#        77    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(concatenate)
#        53    0.000    0.000    0.000    0.000 tensor_shape.py:265(value)
#         4    0.000    0.000    0.000    0.000 array_ops.py:1548(_get_dtype_from_nested_lists)
#         4    0.000    0.000    0.000    0.000 default_types.py:221(__eq__)
#        23    0.000    0.000    0.000    0.000 context.py:934(_handle)
#         1    0.000    0.000    0.021    0.021 <string>:1(<module>)
#        13    0.000    0.000    0.000    0.000 polymorphic_function.py:515(__enter__)
#         2    0.000    0.000    0.000    0.000 ops.py:574(__iter__)
#         1    0.000    0.000    0.000    0.000 ops.py:1136(numpy)
#         5    0.000    0.000    0.000    0.000 types.py:176(__get__)
#         2    0.000    0.000    0.000    0.000 gen_array_ops.py:919(check_numerics)
#        15    0.000    0.000    0.000    0.000 monomorphic_function.py:1831(outputs)
#         1    0.000    0.000    0.000    0.000 gen_math_ops.py:443(add_v2)
#        30    0.000    0.000    0.000    0.000 ops.py:3468(_get_control_flow_context)
#         4    0.000    0.000    0.000    0.000 default_types.py:292(__eq__)
#         4    0.000    0.000    0.000    0.000 context.py:993(scope_name)
#        13    0.000    0.000    0.000    0.000 monomorphic_function.py:119(__exit__)
#         2    0.000    0.000    0.000    0.000 enum.py:442(__iter__)
#         8    0.000    0.000    0.000    0.000 dtypes.py:82(base_dtype)
#        26    0.000    0.000    0.000    0.000 context.py:176(config_proto_serialized)
#        49    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        13    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        26    0.000    0.000    0.000    0.000 trace_type_builder.py:86(deletion_observer)
#        26    0.000    0.000    0.000    0.000 function_spec.py:278(default_values)
#         1    0.000    0.000    0.002    0.002 dataset.py:297(<listcomp>)
#         2    0.000    0.000    0.000    0.000 dataset.py:486(<dictcomp>)
#         7    0.000    0.000    0.001    0.000 constant_op.py:341(_constant_tensor_conversion_function)
#         1    0.000    0.000    0.000    0.000 math_ops.py:2368(reduce_sum_with_dims)
#        13    0.000    0.000    0.000    0.000 function_spec.py:308(is_pure)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2188(sum)
#         8    0.000    0.000    0.000    0.000 enum.py:446(<genexpr>)
#        15    0.000    0.000    0.000    0.000 distribute_lib.py:846(extended)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(sum)
#        12    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 distribution_strategy_context.py:76(_get_per_thread_mode)
#        26    0.000    0.000    0.000    0.000 function_spec.py:283(function_type)
#        26    0.000    0.000    0.000    0.000 function_spec.py:299(input_signature)
#        39    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 distribution_strategy_context.py:366(_get_default_strategy)
#         2    0.000    0.000    0.000    0.000 ops.py:7054(__exit__)
#        13    0.000    0.000    0.000    0.000 ops.py:3690(building_function)
#        13    0.000    0.000    0.000    0.000 trace.py:87(set_metadata)
#         1    0.000    0.000    0.000    0.000 dataset.py:394(<listcomp>)
#         2    0.000    0.000    0.000    0.000 array_ops.py:911(_check_index)
#         3    0.000    0.000    0.000    0.000 dtypes.py:247(__ne__)
#         5    0.000    0.000    0.000    0.000 nest.py:147(is_namedtuple)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2955(prod)
#        13    0.000    0.000    0.000    0.000 polymorphic_function.py:862(_run_functions_eagerly)
#        13    0.000    0.000    0.000    0.000 function_spec.py:339(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 injection.py:1086(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 ops.py:7363(__init__)
#         1    0.000    0.000    0.000    0.000 dataset.py:383(_process_mask)
#        16    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        13    0.000    0.000    0.000    0.000 save_context.py:42(in_save_context)
#        13    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        13    0.000    0.000    0.000    0.000 monomorphic_function.py:1962(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ops.py:1124(_numpy)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         8    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 dataset.py:342(_calculate_rolling_pearson)
#         1    0.000    0.000    0.000    0.000 math_ops.py:2301(reduce_sum)
#         2    0.000    0.000    0.000    0.000 context.py:988(scope_name)
#         1    0.000    0.000    0.000    0.000 enum.py:801(value)
#        21    0.000    0.000    0.000    0.000 type_spec.py:543(__tf_tracing_type__)
#         1    0.000    0.000    0.000    0.000 distribution_strategy_context.py:233(get_strategy)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:435(__exit__)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         2    0.000    0.000    0.000    0.000 default_types.py:240(__init__)
#         1    0.000    0.000    0.000    0.000 dataset.py:392(_create_output_dictionaries)
#         1    0.000    0.000    0.000    0.000 distribution_strategy_context.py:253(has_strategy)
#         8    0.000    0.000    0.000    0.000 array_ops.py:1513(<genexpr>)
#         4    0.000    0.000    0.000    0.000 trace_type_builder.py:188(<genexpr>)
#        11    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 tensor_shape.py:887(rank)
#        13    0.000    0.000    0.000    0.000 trace.py:83(__enter__)
#        13    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 dtypes.py:186(is_compatible_with)
#         1    0.000    0.000    0.000    0.000 dataset.py:359(_process_raw_onsource)
#         2    0.000    0.000    0.000    0.000 ops.py:7044(_restore_name_scope)
#         1    0.000    0.000    0.000    0.000 {method '__array__' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 tensor_shape.py:906(<listcomp>)
#        13    0.000    0.000    0.000    0.000 trace.py:121(__exit__)
#        13    0.000    0.000    0.000    0.000 context.py:168(executor_type)
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsMutableMapping}
#         1    0.000    0.000    0.000    0.000 ops.py:1432(convert_to_tensor_v2_with_dispatch)
#        10    0.000    0.000    0.000    0.000 control_flow_util.py:209(GetContainingXLAContext)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(prod)
#        13    0.000    0.000    0.000    0.000 inspect.py:2783(signature)
#         6    0.000    0.000    0.000    0.000 tensor_shape.py:908(ndims)
#         2    0.000    0.000    0.000    0.000 ops.py:6803(<genexpr>)
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsMapping}
#         1    0.000    0.000    0.000    0.000 distribute_lib.py:298(_require_cross_replica_or_default_context_extended)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 ops.py:7002(__init__)
#         1    0.000    0.000    0.000    0.000 distribute_lib.py:407(__exit__)
#        13    0.000    0.000    0.000    0.000 monomorphic_function.py:116(__enter__)
#         2    0.000    0.000    0.000    0.000 tensor_shape.py:894(dims)
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsMappingView}
#         1    0.000    0.000    0.000    0.000 ops.py:1500(convert_to_tensor_v2)
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsTypeSpec}
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsCompositeTensor}
#         5    0.000    0.000    0.000    0.000 {built-in method tensorflow.python.util._pywrap_utils.IsAttrs}
#         4    0.000    0.000    0.000    0.000 default_types.py:301(__hash__)
#         4    0.000    0.000    0.000    0.000 ops.py:175(__exit__)
#         2    0.000    0.000    0.000    0.000 default_types.py:159(__init__)
#         1    0.000    0.000    0.000    0.000 math_ops.py:1396(maybe_promote_tensors)
#         1    0.000    0.000    0.000    0.000 dataset.py:353(_calculate_spectrogram)
#         1    0.000    0.000    0.000    0.000 dataset.py:377(_process_gps_times)
#         1    0.000    0.000    0.000    0.000 math_ops.py:2213(_may_reduce_to_scalar)
#         4    0.000    0.000    0.000    0.000 default_types.py:230(__hash__)
#         2    0.000    0.000    0.000    0.000 ops.py:1270(get_shape)
#         1    0.000    0.000    0.000    0.000 math_ops.py:2190(_ReductionDims)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2950(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 math_ops.py:2208(_has_fully_defined_shape)
#         1    0.000    0.000    0.000    0.000 injection.py:806(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 dataset.py:368(_process_offsource)
#         8    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 ops.py:169(__init__)
#         4    0.000    0.000    0.000    0.000 enum.py:796(name)
#         2    0.000    0.000    0.000    0.000 dataset.py:480(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 multiarray.py:152(concatenate)
#         1    0.000    0.000    0.000    0.000 {method '__array__' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 contextlib.py:63(_recreate_cm)
#         4    0.000    0.000    0.000    0.000 ops.py:172(__enter__)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2183(_sum_dispatcher)

# %% [markdown]
# We can print the output of the generator to examine its format, which values are returned will depend on which parameters we have requested in the input_variables, and output_variables field in our gf.data function. Both are returned in the form of a dictionary, which can easly be fed into a keras model if the inputs of the model are named similarly to the variable feilds, we will show an example of this later in the notebook.

# %%
# This is the data we will uses as an input examples to out model:
print(f"Dictionary to feed the model: \n {input_data}")

# This is the target data we will use as labels to train our model:
print(f"Dictionary to use as the model labels: \n {output_data}")
# Out:
# Dictionary to feed the model:
#  {'WHITENED_ONSOURCE': <tf.Tensor: shape=(8, 1, 2048), dtype=float16, numpy=
# array([[[-1.215  , -0.03406,  0.1852 , ..., -0.949  ,
#           0.271  ,  1.201  ]],
#
#        [[-1.134  , -2.58   ,  0.8687 , ..., -0.765  ,
#           1.777  , -0.42   ]],
#
#        [[-1.368  , -0.594  , -1.178  , ...,  0.02081,
#           0.1614 ,  1.042  ]],
#
#        ...,
#
#        [[-0.2957 ,  3.229  ,  1.634  , ..., -0.01342,
#           0.727  , -0.4263 ]],
#
#        [[ 1.3125 ,  0.7666 , -1.929  , ..., -1.03   ,
#          -0.2837 , -1.098  ]],
#
#        [[ 0.9756 ,  0.3188 ,  2.764  , ...,  0.8154 ,
#          -0.441  , -1.4    ]]], dtype=float16)>}
# Dictionary to use as the model labels:
#  {'INJECTIONS': <tf.Tensor: shape=(1, 8, 1, 2048), dtype=float32, numpy=
# array([[[[ 0.25261962,  0.2676883 ,  0.279508  , ...,
#            0.        ,  0.        ,  0.        ]],
#
#         [[-0.2885979 , -0.29481485, -0.2930275 , ...,
#            0.        ,  0.        ,  0.        ]],
#
#         [[-0.10134438, -0.11171591, -0.12133908, ...,
#            0.        ,  0.        ,  0.        ]],
#
#         ...,
#
#         [[-0.0972698 , -0.11695402, -0.13541575, ...,
#            0.        ,  0.        ,  0.        ]],
#
#         [[-0.10427686, -0.09242647, -0.07978741, ...,
#            0.        ,  0.        ,  0.        ]],
#
#         [[ 0.19918993,  0.20003176,  0.19937125, ...,
#            0.        ,  0.        ,  0.        ]]]],
#       dtype=float32)>, 'WHITENED_INJECTIONS': <tf.Tensor: shape=(1, 8, 1, 2048), dtype=float32, numpy=
# array([[[[-5.4728114e-03, -4.2752898e-03, -3.1374109e-03,
#           ..., -1.3724074e-09,  5.0142188e-09,
#            1.2938103e-08]],
#
#         [[-3.4765005e-03, -2.3429866e-03, -2.2901271e-03,
#           ...,  7.9862167e-10, -2.7099061e-08,
#           -2.1164141e-08]],
#
#         [[ 2.9764886e-04,  4.4438665e-04,  5.7963282e-04,
#           ...,  4.6924362e-03,  3.9881882e-03,
#            2.7492442e-03]],
#
#         ...,
#
#         [[ 3.0454709e-03,  2.3503832e-03,  1.6184741e-03,
#           ..., -9.1228122e-04, -8.0080220e-04,
#           -4.9329875e-04]],
#
#         [[-7.0914807e-04, -6.6204893e-04, -6.0456851e-04,
#           ..., -4.5050652e-04, -1.5262094e-03,
#           -2.7363526e-03]],
#
#         [[ 3.9376137e-03,  4.0093656e-03,  4.0411125e-03,
#           ..., -1.6390055e-04, -3.9049660e-04,
#           -5.1367295e-04]]]], dtype=float32)>, 'INJECTION_MASKS': <tf.Tensor: shape=(1, 8), dtype=float32, numpy=array([[1., 1., 1., 1., 1., 1., 1., 1.]], dtype=float32)>}

# %% [markdown]
# We can then print some examples from this dataset to examine the output:

# %%
# Use the TensorFlow environment 'env' created earlier with gf.env()
with env:
    # Generate a batch of examples using the composed generator.
    input_data, output_data = next(generator)


# Extract the data from the generator output: 
onsource: tf.Tensor = input_data[gf.ReturnVariables.WHITENED_ONSOURCE.name]
injections: tf.Tensor = output_data[gf.ReturnVariables.INJECTIONS.name][0]
whitened_injections: tf.Tensor = output_data[gf.ReturnVariables.WHITENED_INJECTIONS.name][0]
injection_masks: tf.Tensor = output_data[gf.ReturnVariables.INJECTION_MASKS.name][0]

# Initialize an empty layout for the strain plots.
generated_data_layout: List = []

# Iterate over the multi-injections and their corresponding parameters.
for onsource_, injection, whitened_injection, masks_ in zip(
        onsource,
        injections,
        whitened_injections,
        injection_masks
    ):
    # Create strain plots for each Phenom D and WNB injection with titles displaying the parameter values.
    generated_data_layout.append([
        gf.generate_strain_plot(
            {
                "Onsouce": onsource_,
                "Whitened Injection": whitened_injection,
                "Injection": injection,
            },
            height=400,
            width=800,
            title=f"Example Output. Has Injection: {bool(masks_)}"
        )
    ])

# Arrange the plots in a grid layout and display them in the notebook.
grid = gridplot(generated_data_layout)
output_notebook()
show(grid)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="db94267e-62ea-49db-8e53-6bc85e3df9dd">Loading BokehJS ...</span>
#     </div>
#   <div id="ef44afdb-1ca4-4ddc-a0bc-220595a19be7" data-root-id="p10109" style="display: contents;"></div>
