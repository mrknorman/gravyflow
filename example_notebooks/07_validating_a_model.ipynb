# %%
import os
os.environ['KERAS_BACKEND'] = 'jax'

# Built-in imports
from typing import List, Dict
from pathlib import Path

# Dependency imports: 
import numpy as np
import keras
from keras import ops
import jax
import jax.numpy as jnp
from keras.layers import Input, Permute, Conv1D, MaxPooling1D, Dense, Flatten, Dropout, ELU
from keras.models import Model

# Import the GravyFlow module.
import gravyflow as gf
# Out:
# INFO:2025-12-07 21:52:18,859:jax._src.xla_bridge:812: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-12-07 21:52:18,859 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# W1207 21:52:20.892830 2661066 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.894083 2661067 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.894159 2661070 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.894270 2661068 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.894495 2661069 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.908566 2661071 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.922761 2661065 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.924461 2661064 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.940570 2660616 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.941179 2660616 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.941799 2660616 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.942364 2660616 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.943002 2660616 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.943628 2660616 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.944298 2660616 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1207 21:52:20.944906 2660616 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.

# %%
model = gf.Gabbard2017.pretrained()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = gf.Gabbard2017.pretrained()
#
# File ~/gravyflow/gravyflow/src/model/examples/gabbard_2017.py:384, in Gabbard2017.pretrained(cls, weights_path)
#     378 if not Path(weights_path).exists():
#     379     raise FileNotFoundError(
#     380         f"Pre-trained weights not found at {weights_path}. "
#     381         "Train a model first or download pre-trained weights."
#     382     )
# --> 384 model.load_weights(str(weights_path))
#     385 return model
#
# File ~/miniconda3/envs/gravyflow/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/gravyflow/lib/python3.13/site-packages/keras/src/saving/saving_lib.py:645, in _raise_loading_failure(error_msgs, warn_only)
#     643     warnings.warn(msg)
#     644 else:
# --> 645     raise ValueError(msg)
#
# ValueError: A total of 1 objects could not be loaded. Example error message for object <Conv1D name=Conv1D_1, built=True>:
#
# The shape of the target variable and the shape of the target value in `variable.assign(value)` must match. variable.shape=(64, 8192, 8), Received: value.shape=(64, 1, 8). Target variable: <Variable path=Conv1D_1/kernel, shape=(64, 8192, 8), dtype=float32, value=[[[-1.3138012e-03 -1.8353015e-04 -9.9275634e-04 ...
#    -6.6790311e-04  3.3238791e-03  8.4965397e-04]
#   [-2.5881839e-03  2.6051044e-03 -1.3653147e-03 ...
#     1.4317008e-03  1.8400918e-03  1.9493662e-03]
#   [ 9.7893178e-05 -1.0875780e-03  2.2608959e-03 ...
#    -1.8964179e-03  8.8315783e-04 -1.7495105e-03]
#   ...
#   [ 1.5704543e-04 -1.5459893e-03 -1.0974451e-03 ...
#    -2.1418091e-04 -2.5317797e-03 -2.6803629e-03]
#   [-3.8591446e-05  2.6479210e-03 -2.4418263e-03 ...
#     1.3322406e-03 -2.2359989e-03 -2.3167490e-03]
#   [ 8.6985808e-04 -2.0997319e-03  1.3861256e-03 ...
#    -3.3545871e-03 -1.2673670e-05  1.7756051e-03]]
#
#  [[ 5.2281935e-04  3.0312599e-03 -2.5411053e-03 ...
#     2.1248451e-03 -8.2236808e-04 -2.9183070e-03]
#   [-8.3115115e-04 -1.3631280e-04 -1.2044252e-03 ...
#    -3.0302512e-03  1.0876926e-03  2.9491279e-03]
#   [ 2.1993564e-03 -2.1867105e-03 -9.2383730e-04 ...
#    -2.4045594e-03 -5.2336417e-04  2.5083255e-03]
#   ...
#   [-3.2211756e-03 -4.4966070e-04  2.8911904e-03 ...
#     2.3987251e-03  7.0864614e-04 -8.4179244e-04]
#   [-3.7059607e-04 -1.4617187e-03 -1.7850338e-03 ...
#     2.6626922e-03  8.8215107e-04  1.6486663e-03]
#   [ 1.0413439e-03  1.6966378e-03 -2.4133062e-03 ...
#     1.4447412e-03  2.5440040e-03 -3.3496937e-03]]
#
#  [[ 3.5950588e-04  2.8715483e-03 -2.0890939e-03 ...
#     9.7868033e-05  1.0418957e-03  3.2972833e-03]
#   [-1.2811415e-03 -6.5403292e-05 -3.2588439e-03 ...
#     9.9985115e-04 -2.9164238e-03 -3.1320504e-03]
